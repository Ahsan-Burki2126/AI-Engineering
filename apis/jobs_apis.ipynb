# %%
import requests
import pandas as pd

# %%
r = requests.get("https://arbeitnow.com/api/job-board-api")

# %%
json = r.json()
df = pd.DataFrame(json['data']) 
df.tail()
# Out:
#                                                  slug           company_name  \
# 95  chartermitarbeiter-mit-verantwortung-perspekti...    Aquare Charter GmbH
# 96  werkstudent-oder-masterand-sensorentwicklung-i...  Xylem Water Solutions
# 97  mitarbeiter-fur-den-charter-stutzpunkt-standor...    Aquare Charter GmbH
# 98  communications-consultant-bei-frauwenk-berlin-...               FRAUWENK
# 99  qa-engineer-firmware-mobile-testing-munich-318487                  Bragi
#
#                                                 title  \
# 95  Chartermitarbeiter (m/w/d) mit Verantwortung &...
# 96  Werkstudent oder Masterand Sensorentwicklung (...
# 97  Mitarbeiter (m/w/d) für den Charter-Stützpunkt...
# 98     Communications Consultant (m/w/d) bei FRAUWENK
# 99            QA Engineer - Firmware & Mobile Testing
#
#                                           description  remote  \
# 95  <p>Die Aquare Charter GmbH steht für Urlaub di...   False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   slug          100 non-null    object
#  1   company_name  100 non-null    object
#  2   title         100 non-null    object
#  3   description   100 non-null    object
#  4   remote        100 non-null    bool
#  5   url           100 non-null    object
#  6   tags          100 non-null    object
#  7   job_types     100 non-null    object
#  8   location      100 non-null    object
#  9   created_at    100 non-null    int64
# dtypes: bool(1), int64(1), object(8)
# memory usage: 7.3+ KB

# %%
df["created_at"] = pd.to_datetime(df["created_at"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   slug          100 non-null    object
#  1   company_name  100 non-null    object
#  2   title         100 non-null    object
#  3   description   100 non-null    object
#  4   remote        100 non-null    bool
#  5   url           100 non-null    object
#  6   tags          100 non-null    object
#  7   job_types     100 non-null    object
#  8   location      100 non-null    object
#  9   created_at    100 non-null    datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), object(8)
# memory usage: 7.3+ KB

# %%
df.head()
# Out:
#                                                 slug  \
# 0     showroom-event-feelgood-manager-hamburg-204640
# 1                werkstudent-marketing-hamburg-45919
# 2  dlp-data-leakage-prevention-engineer-munich-12...
# 3  regional-development-manager-everyone-is-welco...
# 4  working-student-machine-learning-engineer-muni...
#
#                   company_name  \
# 0                     1KOMMA5˚
# 1       Triviar Education GmbH
# 2  Mandl. Executives & Experts
# 3       Sirius Facilities GmbH
# 4          Delicious Data GmbH
#
#                                                title  \
# 0  Showroom, Event & Feelgood Manager (m/w/d) - H...
# 1                      Werkstudent Marketing (m/w/d)
# 2     DLP (Data Leakage Prevention) Engineer (m/w/d)
# 3  Regional Development Manager (everyone is welc...
# 4  Working Student Machine Learning Engineer (f/m/d)
#
#                                          description  remote  \
# ...

# %%
df.to_excel('jobs_updated.xlsx')
